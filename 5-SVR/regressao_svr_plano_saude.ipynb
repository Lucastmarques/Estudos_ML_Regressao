# %% [markdown]
# # Regressão com SVR
#
# ## Regressão com kernel linear

# %%
import pandas as pd 

base = pd.read_csv('plano_saude2.csv')

X = base.iloc[:, 0:1].values
y = base.iloc[:, 1].values

from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y.reshape(-1,1))

# %%
from sklearn.svm import SVR

regressor_linear = SVR(kernel='linear')
regressor_linear.fit(X, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
import matplotlib.pyplot as plt 

plt.scatter(X,y)
plt.plot(X, regressor_linear.predict(X), color='red')

# %%
regressor_linear.score(X, y)
# Out:
# 0.458439513430054

# %% [markdown]
# ## Regressão com kernel polinomial

# %%
regressor_poly = SVR(kernel='poly', degree=3)
regressor_poly.fit(X, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.scatter(X,y)
plt.plot(X, regressor_poly.predict(X), color='red')

# %%
regressor_poly.score(X, y)
# Out:
# 0.6452017680102275

# %% [markdown]
# ## Regressão com kernel rbf
#
# Esse modelo exige a padronização do X e Y com o StandardScaler()

# %%
regressor_rbf = SVR(kernel='rbf')
regressor_rbf.fit(X,y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.scatter(X,y)
plt.plot(X, regressor_rbf.predict(X), color='red')

# %%
regressor_rbf.score(X, y)
# Out:
# 0.7561578176049305

# %%
previsao_linear = scaler_y.inverse_transform(regressor_linear.predict(scaler_x.transform([[40]])))
previsao_poly = scaler_y.inverse_transform(regressor_poly.predict(scaler_x.transform([[40]])))
previsao_rbf = scaler_y.inverse_transform(regressor_rbf.predict(scaler_x.transform([[40]])))

print('Previsão Linear: ', previsao_linear[0])
print('Previsão Polinomial: ', previsao_poly[0])
print('Previsão rbf: ', previsao_rbf[0])
# Out:
# Previsão Linear:  1734.8344249696243
# Previsão Polinomial:  1957.3442923802722
# Previsão rbf:  1333.8565074791948
